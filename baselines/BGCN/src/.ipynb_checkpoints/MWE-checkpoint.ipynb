# %%
item_number, column_number = np.random.randint(1, 100), np.random.randint(1, 100)
buffer_item_num.append(item_number)
buffer_column_num.append(column_number)
np.random.random(size=(np.random.randint(1, 100), 2))
buffer_item=np.random.random(size=(item_number, 2))
buffer_column=np.random.random(size=(column_number, 3))
import random
edge_index = [[item, column] for item in range(item_number) for column in range(column_number) if not item==column]
edge_number = np.random.randint(1, len(edge_index))
buffer_edge=np.random.random(size=(edge_number, 1))
edge_index = random.sample(edge_index, edge_number)
edge_index = list(map(list, zip(*edge_index)))
# edge_index.t().contiguous()
buffer_edge_indices=edge_index
buffer_a.append([np.random.randint(0, column_number)])
buffer_r.append([1])

# %%
import os
import torch_geometric
import torch
from tqdm import tqdm
import shutil
from torch.utils.tensorboard import SummaryWriter
import pandas as pd
import numpy as np
import multiprocessing

import utilities
import agent.ppo as agent

def rollout(ppo, data_table):
    item_number, column_number = np.random.randint(1, 100), np.random.randint(1, 100)
    buffer_item_num.append(item_number)
    buffer_column_num.append(column_number)
    np.random.random(size=(np.random.randint(1, 100), 2))
    buffer_item=np.random.random(size=(item_number, 2))
    buffer_column=np.random.random(size=(column_number, 3))
    import random
    edge_index = [[item, column] for item in range(item_number) for column in range(column_number) if not item==column]
    edge_number = np.random.randint(1, len(edge_index))
    buffer_edge=np.random.random(size=(edge_number, 1))
    edge_index = random.sample(edge_index, edge_number)
    edge_index = list(map(list, zip(*edge_index)))
    # edge_index.t().contiguous()
    buffer_edge_indices=edge_index
    buffer_a.append([np.random.randint(0, column_number)])
    buffer_r.append([1])
    
    item_features, edge_indices, edge_features, column_features, column_decision_list = utilities.construct_edge_feature(items=buffer_item, edges=buffer_edge, column_features=buffer_column, eval_baselines=False)
    print('1')
    action = ppo.choose_action(torch.FloatTensor(item_features), edge_features=torch.FloatTensor(edge_features),edge_indices=torch.LongTensor(edge_indices),column_features=torch.FloatTensor(column_features))
    print("2")
    data_table.append(action)

if __name__ == '__main__':
    print('program start')
    ppo = agent.PPO()
    
    buffer_item, buffer_edge, buffer_edge_indices, buffer_column, buffer_a, buffer_r, buffer_item_num, buffer_column_num = list(), list(), list(), list(), list(), list(), list(), list()
    done, ep_r, ep_rwr = False, 0, 0
    for _ in range(5):  # in one episode
        item_number, column_number = np.random.randint(1, 100), np.random.randint(1, 100)
        buffer_item_num.append(item_number)
        buffer_column_num.append(column_number)
        np.random.random(size=(np.random.randint(1, 100), 2))
        buffer_item.append(np.random.random(size=(item_number, 2)))
        buffer_column.append(np.random.random(size=(column_number, 3)))
        import random
        edge_index = [[item, column] for item in range(item_number) for column in range(column_number) if not item==column]
        edge_number = np.random.randint(1, len(edge_index))
        buffer_edge.append(np.random.random(size=(edge_number, 1)))
        edge_index = random.sample(edge_index, edge_number)
        edge_index = list(map(list, zip(*edge_index)))
        # edge_index.t().contiguous()
        buffer_edge_indices.append(edge_index)
        buffer_a.append([np.random.randint(0, column_number)])
        buffer_r.append([1])
        ep_r += 1; ep_rwr += 1
        
    train_data = utilities.GraphDataset(buffer_item, buffer_edge, buffer_edge_indices,
                                            buffer_column, buffer_a, buffer_r,
                                            buffer_column_num, buffer_item_num)
    batch_size = train_data.len()
    train_loader = torch_geometric.loader.DataLoader(train_data, batch_size, shuffle=False)
    for batch in train_loader:
        # print('update function')
        closs, aloss = ppo.update(item_features=batch.item_features, edge_features=batch.edge_features, edge_indices=batch.edge_index, column_features=batch.column_features, actions=batch.actions, rewards=batch.rewards, column_nums=train_data.column_nums, item_nums=train_data.item_nums)
    
    task_pool = multiprocessing.Pool(multiprocessing.cpu_count())
    data_table = multiprocessing.Manager().list()
    for _ in range(100):
        task_pool.apply_async(rollout,  args=(net, data_table, ))
        # rollout(ppo, data_table)
        
    task_pool.close()  
    task_pool.join() 
    print('program end')
# Out:
# program start
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-2dc87efa0165> in <module>
#      74     for _ in range(100):
#      75         # task_pool.apply_async(rollout,  args=(net, data_table, ))
# ---> 76         rollout(ppo, data_table)
#      77
#      78     task_pool.close()
#
# <ipython-input-50-2dc87efa0165> in rollout(ppo, data_table)
#      32     item_features, edge_indices, edge_features, column_features, column_decision_list = utilities.construct_edge_feature(items=buffer_item, edges=buffer_edge, column_features=buffer_column, eval_baselines=False)
#      33     print('1')
# ---> 34     action = ppo.choose_action(torch.FloatTensor(item_features), edge_features=torch.FloatTensor(edge_features),edge_indices=torch.LongTensor(edge_indices),column_features=torch.FloatTensor(column_features))
#      35     print("2")
# ...
